# %%
from image_processing.utils import io, plot
from image_processing.processing import combination, transformation

# %%
img_1 = io.read_image('C:/Users/Maoki/OneDrive - CorpServices/Área de Trabalho/Projetos/Git e GitHub/image-processing-package/teste/img1.jpg')
img_2 = io.read_image('C:/Users/Maoki/OneDrive - CorpServices/Área de Trabalho/Projetos/Git e GitHub/image-processing-package/teste/img2.jpg')
img_3 = io.read_image('C:/Users/Maoki/OneDrive - CorpServices/Área de Trabalho/Projetos/Git e GitHub/image-processing-package/teste/img3.jpg')

# %%
list = [img_1,img_2,img_3]
for i in list:
    plot.plot_image(i)

# %%
result_img = combination.transfer_histogram(img_1,img_2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 result_img = combination.transfer_histogram(img_1,img_2)
#
# File c:\Users\Maoki\OneDrive - CorpServices\Área de Trabalho\Projetos\Git e GitHub\image-processing-package\image_processing\processing\combination.py:16, in transfer_histogram(image1, image2)
#      15 def transfer_histogram(image1, image2):
# ---> 16     matched_image = match_histograms(image1, image2, multichannel=True)
#      17     return matched_image
#
# File c:\Users\Maoki\OneDrive - CorpServices\Área de Trabalho\Projetos\Git e GitHub\image-processing-package\Img_prcs_venv\Lib\site-packages\skimage\_shared\utils.py:438, in channel_as_last_axis.__call__.<locals>.fixed_func(*args, **kwargs)
#     435 channel_axis = kwargs.get('channel_axis', None)
#     437 if channel_axis is None:
# --> 438     return func(*args, **kwargs)
#     440 # TODO: convert scalars to a tuple in anticipation of eventually
#     441 #       supporting a tuple of channel axes. Right now, only an
#     442 #       integer or a single-element tuple is supported, though.
#     443 if np.isscalar(channel_axis):
#
# TypeError: match_histograms() got an unexpected keyword argument 'multichannel'
